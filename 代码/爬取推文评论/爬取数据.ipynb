# %%
#1.爬取b站评论
import requests
import re
import pandas as pd
url="https://api.bilibili.com/x/v2/reply/wbi/main?next=0&type=12&oid=25695998&mode=3&plat=1&web_location=1315875&gaia_source=Athena&w_rid=2cc49066cbf4554013721e0777cfd0bb&wts=1694419867"

# %%
headers={
        "user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 SE 2.X MetaSr 1.0"
}
response=requests.get(url=url,headers=headers)

# %%
content_list=[i["content"]["message"] for i in response.json()["data"]["replies"]]

# %%
df1=pd.DataFrame(content_list,columns=["评论"])
df1
# Out:
#                                                  评论
# 0                   菌藻共生系统是第一次那么系统的了解，感谢🙏已经关注，期待更新！
# 1         之前一直没了解过污水处理，这篇文章很清楚地介绍了藻菌共生系统，学到了学到了[呲牙]
# 2                                      讲的太专业了！受益匪浅！
# 3                   第一次了解到藻菌共生系统能处理污水，而且还安全有效！！[惊喜]
# 4              东华理工学子来串门了，又长新知识啦，继续保持更新[OK][OK][OK]
# 5                       专业的事情就应该交给专业的团队来做，感觉学到了很多东西
# 6                          [兔年][兔年][兔年][兔年][兔年]nice
# 7                            讲的太专业了，太棒了[兔年][兔年][兔年]
# 8   [嘘声][嘘声][嘘声]原来菌藻共生系统有这么多方面的知识，开了眼界了[鼓掌][鼓掌][鼓掌]
# 9                        [兔年][兔年][兔年]很喜欢博主的内容，继续加油呀
# 10                                    学到了学到了[打call]
# 11                        继续保持更新！一定要[星星眼][星星眼][星星眼]
# 12                    学到了学到了，up主继续保持更新哦[微笑][微笑][微笑]
# 13                          [微笑][微笑][兔年]生物污水处理大有可为啊
# 14           太喜欢博主的内容了，感谢分享[脱单doge][脱单doge][脱单doge]
# 15                学习藻菌共生系统，了解污水处理新知识[星星眼][星星眼][星星眼]
# 16                [星星眼][星星眼][星星眼][星星眼]藻菌共生系统原来有如此大用
# ...

# %%
import requests
import re
import pandas as pd
url="https://api.bilibili.com/x/v2/reply/wbi/main?next=0&type=12&oid=25697365&mode=3&plat=1&web_location=1315875&gaia_source=Athena&w_rid=f0121f88cbb4587dc14944edcfec9a1c&wts=1694420579"
headers={
        "user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 SE 2.X MetaSr 1.0"
}
response=requests.get(url=url,headers=headers)
content_list=[i["content"]["message"] for i in response.json()["data"]["replies"]]
df2=pd.DataFrame(content_list,columns=["评论"])
df2
# Out:
#                                                    评论
# 0           [大哭][大哭][大哭]干货太多了，看不过来，不过要保持更新阿[给心心][给心心]
# 1                          学习了污水处理新政策，谢谢UP主[星星眼][星星眼]
# 2                                   很全面地了解了新技术！！[星星眼]
# 3           内容很干货排版很新颖继续保持更新哦[脱单doge][脱单doge][脱单doge]
# 4   污水处理我自己了解到的是化学方法为主，经济实惠但带来很多污染，如果有更多的生物方法还能赋能未...
# 5     这个团队有好多漂亮的小姐姐，人好玩还优秀！大家快快关注！[星星眼][星星眼][星星眼][微笑]
# 6                                   支持生物赋能污水处理[打call]
# 7                                                 好厉害
# 8                                              知识科普全面
# 9                                                [支持]
# 10  东华理工学子来啦，以前对污水处理不太了解，现在看过文章之后感觉学到了很多东西。[星星眼][星...
# 11                                     [给心心][给心心]up加油
# 12                     对于政策这块的了解比较少，所以感谢这么具体的科普[doge]
# 13                                                娃哇哇
# 14          这篇文章让我对污水的生物赋能处理有了更清晰的认知[星星眼][星星眼][星星眼]支持
# 15                                                学到啦
# ...

# %%
import requests
import re
import pandas as pd
url="https://api.bilibili.com/x/v2/reply/wbi/main?next=0&type=12&oid=25698057&mode=3&plat=1&web_location=1315875&gaia_source=Athena&w_rid=4150750890657392be099b861ce649db&wts=1694420616"
headers={
        "user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 SE 2.X MetaSr 1.0"
}
response=requests.get(url=url,headers=headers)
content_list=[i["content"]["message"] for i in response.json()["data"]["replies"]]
df3=pd.DataFrame(content_list,columns=["评论"])
df3
# Out:
#                                             评论
# 0                          第一次那么全面知道菌藻共生系统的两面性
# 1                                        要涨脑子了
# 2                                         学会啦！
# 3                                         学到！！
# 4                             真的好有意思啊！科普内容好详细🤩
# 5                     [兔年][兔年][兔年][兔年][兔年][兔年]
# 6                    菌藻共生系统，不错不错，讲的不错，继续保持[兔年]
# 7                                       讲的太好啦！
# 8            原来还有菌藻共生系统这种东西，学到了学到了[兔年][兔年][兔年]
# 9                        菌藻的两面性真神奇[哦呼][哦呼][哦呼]
# 10                                 爱看爱学多发[星星眼]
# 11           感谢up主分享，学习到了很多新知识[脱单doge][脱单doge]
# 12                         第一次这么全面了解藻菌共生系统[OK]
# 13             感谢up主的分享，让我了解到藻菌系统[微笑][微笑][给心心]
# 14                藻菌共生系统新知识太干货了[星星眼][星星眼][星星眼]
# 15             继续保持更新哦[脱单doge][脱单doge][脱单doge]
# 16            藻菌共生系统原来是这样子的啊，哎呀学到了[兔年][兔年][兔年]
# 17                 第一次了解到藻菌共生系统[星星眼][星星眼][星星眼]
# 18  排版很好看内容很丰富，继续保持更新哦[脱单doge][脱单doge][脱单doge]
# ...

# %%
import requests
import re
import pandas as pd
url="https://api.bilibili.com/x/v2/reply/wbi/main?next=0&type=12&oid=25710943&mode=3&plat=1&web_location=1315875&gaia_source=Athena&w_rid=a0fc98ede2f5e854f55b9ca259589df3&wts=1694420659"
headers={
        "user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36 SE 2.X MetaSr 1.0"
}
response=requests.get(url=url,headers=headers)
content_list=[i["content"]["message"] for i in response.json()["data"]["replies"]]
df4=pd.DataFrame(content_list,columns=["评论"])
df4
# Out:
#                                                    评论
# 0                            很专业，一定要保持更新哦[OK][OK][OK]
# 1   以前对污水处理了解的真的非常少，只是对生活污水的处理有一些了解，现在看完文章才了解到原来污水...
# 2                        能了解到这么多污水处理的知识真好[鼓掌][鼓掌][鼓掌]
# 3                                        科普的很好，期待更多科普
# 4                                [兔年][兔年][兔年][兔年][兔年]
# 5                了解到了这么多污水分类，真开心[打call][打call][打call]
# 6                                               真是太棒啦
# 7            了解污水处理新知识，争做时代环保新青年[打call][打call][打call]
# 8                                   很喜欢[哦呼]能不能一直保持更新呀
# 9                                       干货满满！[脱单doge]
# 10                               多多更新，内容很棒，支持了[打call]
# 11                       看了up主的文章感觉受益匪浅，希望一直保持更新哦[OK]
# 12                很喜欢up主分享的内容，希望继续保持更新[嗑瓜子][嗑瓜子][嗑瓜子]
# 13               一定要保持更新哦[打call][打call][打call][打call]
# 14                        很棒继续保持[打call][打call][打call]
# 15                     很棒很喜欢[打call][打call][打call]继续保持
# ...

# %%
import pandas as pd

# 垂直拼接数据框
df_concat = pd.concat([df1, df2, df3, df4], axis=0)

# %%
df_concat.to_excel("评论整合.xlsx")
